# %% [markdown]
# Task-1

# %%
var=input("Enter a string : ")
out=" "
for i in range(len(var)-1,-1,-1):
  out=out+var[i]
print(out)
# Out:
# Enter a string : CSE110
#  011ESC

# %% [markdown]
# Task-2

# %%
st1="12345"
st2=2

for i in range(st2,-1,-1):
  print(st1[i],end="")
for i in range(st2+1,len(st1),+1):
  print(st1[i],end="")
# Out:
# 32145

# %% [markdown]
# Task-3

# %%
v=input()
var=True

for i in range(-1,len(v),1):
  if v[i]!="1" and v[i]!="0":
    var=False

if var==True:
  print('Binary Number')

else:
  print('Not a Binary Number')
# Out:
# 12344ab0
# Not a Binary Number

# %% [markdown]
# Task -1

# %%
var=input()
out=''
for idx in range(-1,-(len(var)+1),-1):
  out=out+(var[idx])
print(out)
# Out:
# 011ESC

# %% [markdown]
# Task-2

# %%
v1=input()
v2=int(input())
out=''
for idx in range(v2,-1,-1):
  out=out+(v1[idx])
for idx in range(v2+1,len(v1),1):
  out=out+(v1[idx])
print(out)
# Out:
# 32145

# %% [markdown]
# Task 3

# %%
v='011010101'
v2=True

for i in range(0,len(v),1):
  if v[i]!='0' and v[i]!='1':
    v2=False
if v2==True:
  print('Binary Number')
else:
  print('Not a Binary Number')
# Out:
# Not a Binary Number

# %% [markdown]
# Task 4

# %%
v=input()
out=''
for i in range(0,len(v),1):
  if (v[len(v)-2:len(v):1])=='er':
    p=v[0:len(v)-2:1]
print(p)
# Out:
# stronger
# strong

# %%
v=input()
out=''
v1=''
for i in range(0,len(v),1):
  v1=v1+v[i]
print(v1)
if (v1[len(v1)-2:len(v1):1])=='er':
  p=v[0:len(v)-2:1]
  print(p+'est')
elif (v1[len(v1)-3:len(v1):1])=='est':
  print(v)
elif len(v)<4:
  print(v)
elif len(v)>3:
  print(v+'er')
# Out:
# ber
# ber
# best

# %%
if (v1[len(v1)-2:len(v1):1])=='er':
  p=v[0:len(v)-2:1]

# %% [markdown]
# Task-5

# %%
v='Dream'
out=''
for i in range(0,len(v),1):
  out=out+v[i]
  print(out)
# Out:
# D
# Dr
# Dre
# Drea
# Dream

# %% [markdown]
# Task-08

# %%
v='abcd'
out=''
for i in range(1,len(v),2):
  if ord(v[i])>=97 and ord(v[i])<=122:
    c=ord(v[i])
    c=c-32
    out=out+chr(c)
  else:
    out=out+c
print(out)
# Out:
# BD

# %%
ord('a')
# Out:
# 97

# %%
#Manual process of upper() function
var="CSE110 is easy" #cse110 is easy
out=""
for idx in range(1,len(var),2):
  if ord(var[idx])>=97 and ord(var[idx])<=122:
    ascii=ord(var[idx])
    ascii=ascii-32
    out=out+chr(ascii)
  else:
    out=out+var[idx]
print(out)
# Out:
# S10I AY

# %%
v='12345'
v2='abcde'
out=''
for i in range(len(v)):
  out=out+v[i]
  out=out+v2[i]
print(out)
# Out:
# 1a2b3c4d5e

# %%
string1 = "abcdef"
string2 = "213456"
result = ""

for i in range(len(string1)):
    if i % 2 == 0:  # Even index position
        result += string1[i]
   # else:  # Odd index position
       # result += string2[i]

print(result)
# Out:
# ace

# %%
w=True
x=300
print(w,',',x)
# Out:
# True , 300

# %%
v='hunger'
for i in range(len(v)):
  print(v[i],':',ord(v[i]))
# Out:
# h : 104
# u : 117
# n : 110
# g : 103
# e : 101
# r : 114

# %%
v='abcd'
for i in range(len(v)):
  if v[i]=='z':
    print('a',end='')
  elif v[i]=='Z':
    print('A',end='')
  else:
    m=ord(v[i])
    n=(m+1)
    k=chr(n)
    print(k,end='')
# Out:
# bcde

# %%
v='AAABBBBCDDBBECE'
out=''
for i in range(len(v)):
  if len(out)==0:
    out=out+(v[i])
  elif v[i]==out[-1]:
    pass
  elif v[i]!=out[-1]:
    out=out+(v[i])
print(out)
# Out:
# ABCDBECE

# %%
v='ABCD, efgh'
index=0
for i in range(len(v)):
  if v[i]==',':
    index=i
l=v[0:index:]
print(l)
r=v[index+2::]
if len(r)>len(l):
  large=r
  small=len(l)
elif len(l)>len(r):
  large=l
  small=len(r)
else:
  large=small
  small=len(r)
final=''
# Out:
# ABCD
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fdefc44bd294> in <cell line: 9>()
#      14   small=len(r)
#      15 else:
# ---> 16   large=small
#      17   small=len(r)
#      18 final=''
#
# NameError: name 'small' is not defined

# %%
i = 10
while(i >= -20):
    if(i < 0):
        test = " != "
        test = str(i//2) + test + str(int(i/2))
    else:
        test = " == "
        test = str(i//2) + test + str(int(i/2))
    print(test)
    i -= 5
# Out:
# 5 == 5
# 2 == 2
# 0 == 0
# -3 != -2
# -5 != -5
# -8 != -7
# -10 != -10

# %%
v='ABCDENDFGH, ijkl'
index=0
for i in range(len(v)):
  if v[i]==',':
    index=i
l=v[0:index:]
print(l)
r=v[index+2::]
if len(r)>len(l):
  large=r
  small=len(l)
elif len(l)>len(r):
  large=l
  small=len(r)
else:
  small=len(l)
final=''
for i in range(small):
  final=final+l[i]+r[i]
print(final)
k=large[small::]
print(k)
final=final+k
print(final)
# Out:
# ABCDENDFGH
# AiBjCkDl
# ENDFGH
# AiBjCkDlENDFGH

# %%
test = ""
i = 0
j = 0
k = 15
test = "-->"
while i < 5:
    j = k - 1
    k -= 1
    while j > 10:
        test = str(i + j) + "-->" + test
        print(test)
        j -= 1
    i += 1
# Out:
# 14-->-->
# 13-->14-->-->
# 12-->13-->14-->-->
# 11-->12-->13-->14-->-->
# 14-->11-->12-->13-->14-->-->
# 13-->14-->11-->12-->13-->14-->-->
# 12-->13-->14-->11-->12-->13-->14-->-->
# 14-->12-->13-->14-->11-->12-->13-->14-->-->
# 13-->14-->12-->13-->14-->11-->12-->13-->14-->-->
# 14-->13-->14-->12-->13-->14-->11-->12-->13-->14-->-->

# %%
v='ijkl, ABCDENDFGH'
index=0
for i in range(len(v)):
  if v[i]==',':
    index=i
l=v[0:index:]
r=v[index+2::]
if len(r)>len(l):
  large=r
  small=len(l)
elif len(l)>len(r):
  large=l
  small=len(r)
else:
  small=len(l)
final=''
for i in range(small):
  final=final+l[i]+r[i]

k=large[small::]

final=final+k
print(final)
# Out:
# iAjBkClDENDFGH
