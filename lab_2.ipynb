# %% [markdown]
# Task-1

# %%
num1=int(input('Enter a number'))
num2=int(input('Enter another number'))
sum=num1+num2
product=num1*num2
difference=num1-num2
print('Sum =',sum)
print('Product = ',product)
print('Difference =',difference)
# Out:
# Enter a number4
# Enter another number5
# Sum = 9
# Product =  20
# Difference = -1

# %% [markdown]
# Task-2

# %%
import math
radious=float(input('Enter a radius'))

area=math.pi * radious**2
print('Area is',area)
circumference=2*math.pi*radious
print('Circumference is',circumference)
# Out:
# Enter a radius4
# Area is 50.26548245743669
# Circumference is 25.132741228718345

# %% [markdown]
# Task-3

# %%
num1=int(input('Enter a number :'))
num2=int(input('Enter another number : '))
if num1>num2:
  print( "First is greater")
elif num1<num2:
  print( "Second is greater")
elif num1==num2:
  print( "The numbers are equal")
# Out:
# Enter a number11
# Enter another number11
# The numbers are equal

# %% [markdown]
# Task-4

# %%
num1=int(input('Enter a number'))
num2=int(input('Enter another number'))

if num1>num2:
  print(num1-num2)
elif num2>num1:
  print(num2-num1)
elif num1==num2:
  print(0)
# Out:
# Enter a number-40
# Enter another number-4
# 36

# %% [markdown]
# Task-5

# %%
num1=int(input('Enter a number'))

if num1%2!=0:
  print('The number is odd')
else:
  print('The number is even')
# Out:
# Enter a number-44
# The number is even

# %% [markdown]
# Task-6

# %%
num=int(input('Enter a number'))
if num%2==0 or num%5==0:
  print(num)
else:
  print("Not a multiple of 2 OR 5")
# Out:
# Enter a number3
# Not a multiple of 2 OR 5

# %% [markdown]
# Task-7

# %%
num=int(input('Enter a number '))
if num%2==0 and num%5==0:
  print('Multiple of 2 and 5 both')
elif num%2==0 or num%5==0:
  print(num)
else:
  print('Not a multiple we want')
# Out:
# Enter a number 17
# Not a multiple we want

# %% [markdown]
# Task-8

# %%
num=int(input('Enter a number '))
if num%2==0 and num%5==0:
  print(num)

else:
  print('Not Multiple of 2 and 5 both')
# Out:
# Enter a number 6
# Not Multiple of 2 and 5 both

# %% [markdown]
# task-9

# %%
user_second=int(input('Enter Total Second'))

hours=user_second//3600
reminder=user_second%3600
min=reminder//60
second=reminder%60
print('Hours:',hours ,'Minutes:',min,'Seconds:',second)
# Out:
# Enter Total Second10000
# Hours: 2 Minutes: 46 Seconds: 40

# %% [markdown]
# task-10 step1

# %%
#Validation Check
hours=int(input('Enter total hours'))

if 0<=hours<=168:
  print()
elif hours<0:
  print('Hour cannot be negative')
elif 168<hours:
  print('Impossible to work more than 168 hours weekly')
# Out:
# Enter total hours200
# Impossible to work more than 168 hours weekly

# %% [markdown]
# task10 step2

# %%
hours=int(input('Enter total hours : '))
var1=(hours-40)
var2=var1*300
if hours<=40:
  print(hours*200)

elif hours>=40:

  print(8000+var2)
# Out:
# Enter total hours30
# 6000

# %% [markdown]
# Task-10

# %%
hours=int(input('Enter total hours'))
var1=(hours-40)
var2=var1*300
if 0<=hours<=168:
  if hours<=40:
   print(hours*200)
  elif hours>40:
   print(8000+var2)

elif hours<0:
  print('Hour cannot be negative')
elif 168<hours:
  print('Impossible to work more than 168 hours weekly')
# Out:
# Enter total hours170
# Impossible to work more than 168 hours weekly

# %% [markdown]
# Task 11

# %%
s=int(input('Enter a number : ' ))
var=12000/(4+s**2/14900)
if s<100:
  print(3000-125*s**2)
elif s>=100:
  print(var)
# Out:
# Enter a number : 3
# 1875

# %% [markdown]
# Task-12

# %%
time = int(input('Enter your meal time :'))

if 0<=time<24:
  if 4<=time<=6:
    print('Breakfast')
  elif 12<=time<=13:
    print('Lunch')
  elif 16<=time<=17:
    print('Snakes')
  elif 19<=time<=20:
    print('Dinner')
  else:
    print('Patience is a virtue')
else:
  print('Wrong time')
# Out:
# Enter your meal time :4
# Breakfast

# %% [markdown]
# Task-13

# %%
marks=int(input('Enter your Marks  :'))
if 0<=marks<=100:
  if 90<=marks<=100:
    print('A')
  elif 80<=marks<=89:
    print('B')
  elif 70<=marks<=79:
    print('C')
  elif 60<=marks<=69:
    print('D')
  elif 50<=marks<=59:
    print('E')
  elif marks<50:
    print('F')
else:
  print('Invalid Marks')
# Out:
# Enter your Marks  :55
# E

# %% [markdown]
# Task-14

# %%
distance=float(input())/1000
time=float(input())/3600
v=distance/time
print(v,'km/h')

if v<60:
  print('Too slow. Needs more changes.')
elif  60<=v<=90:
  print('Velocity is okay. The car is ready!')
elif 90<v:
  print('Too fast. Only a few changes should suffice.')
# Out:
# 25400
# 3600
# 25.4 km/h
# Too slow. Needs more changes.

# %% [markdown]
# Task-15

# %%
cgpa=float(input('Enter your CGPA :'))
credit=int(input('Enter your total completed Credit :'))

if credit>=30:
  if 3.80<=cgpa<=3.89:
    print('The student is eligible for a waiver of 25 percent.')
  elif 3.90<=cgpa<=3.94:
    print('The student is eligible for a waiver of 50 percent.')
  elif 3.95<=cgpa<=3.99:
    print('The student is eligible for a waiver of 75 percent.')
  elif cgpa==4.00:
    print('The student is eligible for a waiver of 100 percent.')

else:
  print('The student is not eligible for a waiver')
# Out:
# Enter your CGPA :4.00
# Enter your total completed Credit30
# The student is eligible for a waiver of 100 percent.

# %%
num=5
while num<20:
  print(num)
  num+=5
# Out:
# 5
# 10
# 15

# %%
total = 0
num = 2

while num <= 100:
    if num % 2 == 0 and num % 7 == 0:
        total += num
    num += 1

print("Sum of even numbers divisible by 7 from 1 to 100:", total)
# Out:
# Sum of even numbers divisible by 7 from 1 to 100: 392

# %%
num = 2

while num <= 100:
    if num % 2 == 0 and num % 7 == 0:
        print(num)
    num += 1
# Out:
# 14
# 28
# 42
# 56
# 70
# 84
# 98

# %%
num=1
sum=0
while num<=100:
  if num%2==0 and num%7==0:
    print(num)
    print(sum)
    sum=sum+num
  num=num+1
print(sum)
# Out:
# 14
# 0
# 28
# 14
# 42
# 42
# 56
# 84
# 70
# 140
# 84
# 210
# 98
# 294
# 392
