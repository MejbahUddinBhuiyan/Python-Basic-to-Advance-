# %% [markdown]
# Task-1

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# Task-2

# %%
print(54+56)
# Out:
# 110

# %% [markdown]
# Task-3

# %%
season = 'Summer'
year =2023
print(season)
print(year)
# Out:
# Summer
# 2023

# %% [markdown]
# Task-4

# %%
name= input('Enter your name : ')
print('Your name is '+name)
# Out:
# Enter your name : Mejbah
# Your name is Mejbah

# %% [markdown]
# Task-5

# %%
M= int(input())
N= int(input())
result=(M**N)
final_result=str(result)
M_final=str(M)
N_final=str(N)
print(M_final+'^'+N_final+':'+final_result)
# Out:
# 10
# 3
# 10^3:1000

# %% [markdown]
# Task-6

# %%
n= int(input())
corner=4
reminder=(n%corner)
final_result=(n-reminder)
print('Maximum amount of weight',final_result)
# Out:
# 9
# Maximum amount of weight 8

# %%
n=int(input())
corner= 4
store_weight=(n//4)
final_weight=(4*store_weight)
print('maximum amount of weight',final_weight)
# Out:
# 9
# maximum amount of weight 8

# %% [markdown]
# Task-7

# %%
A=int(input('Enter number 1 : '))
B=int(input('Enter number 2 : '))
C=int(input('Enter number 3 : '))
D=float(input('Enter number 4 : '))
result=(A**C+B*A-D/3)
final_result=int(result)
print('The answer is ',final_result)
# Out:
# Enter number 1 : 2
# Enter number 2 : 6
# Enter number 3 : 8
# Enter number 4 : 1.3
# The answer is  267

# %% [markdown]
# Task-8

# %%
number_chocolate=int(input())
distribute= number_chocolate//3
reminder = number_chocolate%3
distribute_f =str(distribute)
reminder_f = str(reminder)
print('Each friend will receive '+distribute_f +' chocolates')
print('The number of remaining chocolates is '+reminder_f)
# Out:
# 50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2

# %% [markdown]
# Task-9

# %%
M=input()
N=input()
print(N+M)
# Out:
# 5
# 2
# 25

# %% [markdown]
# Task-10

# %%
num1=int(input())
num2=float(input())
num3=int(input())

num1_f=str(num1)
num2_f=str(num2)
num3_f=str(num3)

#print(num1_f+','' ' + num2_f+','' ' +num3_f)
print(num1_f+',',num2_f+',',num3_f)
sub=(num1+num2)
sub_f=str(sub)
print(sub_f+num3_f)
# Out:
# 3
# 11.57
# 7
# 3, 11.57, 7
# 14.577

# %%
num1=int(input())
num2=float(input())
num3=int(input())


num1_f=str(num1)
num2_f=str(num2)
num3_f=str(num3)

print('The inputs: '+num1_f+',',num2_f+',',num3_f)
sub=(num1+num2)
sub_f=str(sub)
print('The result is',sub_f+num3_f)
# Out:
# 3

# %% [markdown]
# Task  11

# %%
num1=int(input())
if num1%2==0:
  print(True)
else:
  print(False)
# Out:
# -26
# True
